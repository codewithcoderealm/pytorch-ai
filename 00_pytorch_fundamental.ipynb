# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithcoderealm/pytorch-ai/blob/main/00_pytorch_fundamental.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 00. PyTorch Fundamental

# %%
print("Hello I'm execited to learn PyTorch!")
# Out:
# Hello I'm execited to learn PyTorch!

# %%
import torch
print(torch.__version__)
# Out:
# 2.11.0+cu128

# %%
# !nvidia-smi
# Out:
# Thu Jun 25 02:54:47 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
